# %% [markdown]
# # Lab 1 - Python e Google Colab
#
# Michael Wood | 2026-9-23
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/f/f8/Python_logo_and_wordmark.svg" height="150">

# %% [markdown]
# ## Indice
#
# 1. Cosa _è_ un Jupyter notebook?
# 2. Cosa _è_ Google Colab?
# 3. Cosa _è_ python?
# 4. Ambiente
# 5. Numpy
# 6. Calcolo matriciale e parallelizzazione
# 7. Semplice progetto di codice
#
#
# ## Obiettivi di apprendimento
#
# - La differenza tra il linguaggio python e l'interprete
# - La sintassi di base per variabili, controllo di flusso e utilizzo dei pacchetti
# - Capire come sono realizzati e come funzionano i pacchetti
# - Vedere le difficoltà della gestione dell'ambiente e della moltiplicazione matriciale
# - Vedere l'importanza della documentazione del codice

# %% [markdown]
# ## Termini
#
# Il testo in **grassetto** apparirà qui.
#
# Come in molti ambiti della tecnologia e della scienza, esiste un linguaggio informale semplice e uno formale più preciso.
#
# | Informale EN | Informale IT | Tecnico EN | Descrizione |
# | --- | --- | --- | --- |
# | File/Code | Codice | Script, source | Un file di comandi python che può essere eseguito direttamente |
# | Folder | Cartella | Directory | Posizione su un computer |
# | Run | Girare | Execute | Legge ed esegue ogni riga di codice python |
# | Program (python) | App (pitone) | Interpreter (python) | Il programma che compila ed esegue il codice python su un computer |
# | Notebook | Notebook | Jupyter Notebook | Documento che contiene sia codice eseguibile che testo formattato |
# | Is | È | Assignment | Salvare i dati in una variabile |
# | Error | Errore | Exception | Il motivo per cui un codice non è riuscito a essere eseguito |
# | -- | -- | Type | Gli oggetti python hanno sempre un tipo, come una lista o un float |
# | -- | -- | Object | Un tipo di dato che contiene sia dati che codice |
# | -- | -- | Function | Una porzione di codice che può essere eseguita semplicemente richiamando il nome della funzione |
# | -- | -- | Class | Un tipo di oggetto definito dall'utente che contiene sia dati che codice (metodi) |
# | -- | -- | Method | Una funzione all'interno di una classe |
# | -- | -- | Initialize | Creare un nuovo oggetto a partire da una classe |
# | -- | -- | Environment |
# | -- | -- | Module | Un file di codice che non viene eseguito direttamente ma viene importato nel tuo script principale |
# | -- | -- | Package | Una cartella contenente molti moduli correlati, come `tensorflow` |
# | -- | -- | Library | Di solito si riferisce all'insieme di pacchetti usati per una particolare applicazione |

# %% [markdown]
# # Cosa _è_ un Jupyter notebook?
#
# <img src="https://github.com/woodjmichael/PV-based-systems-lab/blob/main/jupyter.png?raw=true" width="200">
#
#
# Ebbene, è proprio questo!
#
# Un **notebook** Jupyter unisce in un unico file:
# - Testo, tabelle e immagini facili da leggere
# - **Codice** che puoi **eseguire** direttamente
#
# I notebook sono ottimi per l'apprendimento e gli esperimenti.
#
# Il software "in produzione" (ad es. Chrome) di solito non è un notebook.
#
# Questo è un blocco di testo, o "Markdown".

# %%
# this is a code block
# click the arrow on the left to run it
6*7

# %% [markdown]
# # Cosa _è_ Google Colab?
# <img src="https://raw.githubusercontent.com/woodjmichael/polimi-a2a-machine-learning-course/main/images/colab.jpg?raw=true" width="200">
# <br>
# <img src="https://raw.githubusercontent.com/woodjmichael/polimi-a2a-machine-learning-course/main/images/colab.png?raw=true" width="700">
#
# Ebbene, è anche questo!
#
# Colab (Colaboratory) ti permette di eseguire codice su computer aggiuntivi del cloud Google all'interno di un Jupyter notebook.
#
# È ottimo per l'apprendimento e piccoli esperimenti.
#
# Ma non puoi eseguire codice per molte ore, specialmente se usi una GPU.

# %% [markdown]
# # Cosa _è_ python?
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/a/a3/Monty_Python_Live_02-07-14_12_56_41_%2814415567757%29.jpg/1280px-Monty_Python_Live_02-07-14_12_56_41_%2814415567757%29.jpg" width="400">
#
# _Dal "Ministry of Silly Walks" dei Monty Python_
#
# <!-- <img src="https://github.com/woodjmichael/PV-based-systems-lab/blob/main/python.png?raw=true" width="300"> -->
#
# <!-- <img src="https://upload.wikimedia.org/wikipedia/commons/8/8e/Monty_Python_Live_02-07-14_13_04_42_%2814598710791%29.jpg" width="300"> -->
#
#
# In realtà sono due cose diverse:
# 1. Un **linguaggio** di programmazione (come il C)
# 2. Un programma **interprete** per eseguire file `.py` scritti in python

# %% [markdown]
# ## Linguaggio
#
# Python può essere letto abbastanza facilmente, dato che usa parole inglesi:
#
# ```python
# while max(y) < 10 and iteration < 10:
#     if x is in valid_inputs:
#         y.append(x)
#     else:
#         raise ValueError
#     iteration += 1
# ```
#
# E quando viene usato **con criterio**, anche operazioni complesse possono diventare rapidamente comprensibili.
#
# ```python
# data_upsampled = data_raw.dropna().resample('1h').interpolate(method='linear')
# ```
#
# Di seguito trovi un comando valido in python, che stampa il celebre "Zen of Python".

# %%
import this

# %% [markdown]
# Se la sintassi è sbagliata, il computer non capirà.

# %%
print('hello!'

# %% [markdown]
# Prova a correggere il comando qui sopra. Cosa manca?
#
# Sentiti libero di sperimentare con il codice, non puoi rompere nulla.

# %% [markdown]
# ### Operazioni
#
# Operazioni matematiche, in pratica.
#
# Questa **assegnazione** prende sempre ciò che si trova a destra di `=` e lo salva a sinistra.
#
# `I` _è_ `5`.

# %%
I=5     # current
R=0.01  # resistence

# %% [markdown]
# I commenti iniziano con `#` e non fanno nulla.
#
# In un notebook, digitare semplicemente una variabile _sull'ultima riga_ di un blocco di codice la visualizza.

# %%
# I is 5
I

# %% [markdown]
# Aritmetica: $+,-,/,*,$ e $**$ per gli esponenti.
#
# Il notebook ricorda `I` e `R`, e tutto ciò che abbiamo già eseguito sopra.

# %%
power = I**2 * R
power

# %% [markdown]
# Logica: $<,>,<=,>=,==$ (uguale a), $!=$ (diverso da).
#
# Anche `and`, `not`, e `or`.

# %%
power == I

# %%
(R <= 1) or (R >= 1)

# %% [markdown]
# ### Oggetti
#
# Ogni **oggetto** in python ha un **tipo**, come un float (numero decimale a virgola mobile a 32 bit).

# %%
type(R)

# %% [markdown]
# #### Stringa
#
# Una stringa (tipo "str") è semplicemente testo.

# %%
coin = 'Dogecoin'
type(coin)

# %% [markdown]
# La maggior parte delle operazioni sulle liste (vedi sotto) possono essere fatte anche su una stringa.

# %%
coin[0]

# %% [markdown]
# #### Lista
#
# Una lista è una serie dello stesso tipo di oggetto:

# %%
coins = ['Dogecoin','Bitcoin','Ethereum'] + ['Litecoin'] # concatenate
coins

# %% [markdown]
# Leggi il primo elemento della lista:
#
# >NB: Python è "a indice zero" ("zero-indexed"), quindi il primo valore è sempre "numero 0"

# %%
coins[0]

# %% [markdown]
# Modifica un elemento:

# %%
coins[1] = 'Avalanche'
coins

# %% [markdown]
# Aggiungi alla lista

# %%
coins.append('Dogecoin')
coins

# %% [markdown]
# Rimuovi dalla lista

# %%
coins.remove('Ethereum')
coins

# %% [markdown]
# È facile eseguire una piccola operazione su ogni elemento di una lista:

# %%
coins_length = [len(coin) for coin in coins]
coins_length

# %% [markdown]
# #### Dizionario
#
# Questo è forse l'oggetto python standard più potente e comune.
#
# È un tipo di lista con tre differenze principali:
# - L'indice è di solito costituito da *chiavi* di tipo stringa invece che da valori interi di *indice*
# - In ogni elemento del dizionario puoi mettere quello che vuoi
# - Usiamo `{` invece di `[`, ma sempre `[` per accedere agli elementi

# %%
coin_value = {'Bitcoin':48625.24,'Ethereum':2010.17,'Dogecoin':0.08}
coin_value['Dogecoin']

# %% [markdown]
# ### Controllo di flusso
#
# Una grande sfida nella programmazione è controllare quale codice viene eseguito dato un certo input X o una certa condizione Y.
#
# Per esempio potresti voler far eseguire un codice solo una volta al giorno, a mezzanotte.

# %% [markdown]
# #### For
#
# A volte vogliamo eseguire del codice molte volte.
#
# `range(N)` crea una lista di numeri interi che inizia da `0`, con lunghezza `N`.
#
# Questo ciclo `for` verrà eseguito 6 volte:

# %%
for i in range(6):
    print(i,'hello!')

# %% [markdown]
# Spesso vogliamo accedere a ogni elemento `in` qualcosa:

# %%
for s in 'hello!':
    print(s)

# %% [markdown]
# E se vuoi anche l'indice `i`:

# %%
for i,s in enumerate('hello!'):
    print(i,s)

# %% [markdown]
# #### If.. Else

# %% [markdown]
# Altre volte vogliamo eseguire il codice solo in base a una condizione.

# %%
if 5<10:
    print('its true!')

# %% [markdown]
# ### Funzioni
#
# Il codice che usiamo spesso può essere salvato in una funzione e poi *chiamato*.
#
# <img src="https://raw.githubusercontent.com/woodjmichael/polimi-a2a-machine-learning-course/main/images/function.png?raw=true" width="600">

# %%
def calculate_power(resistance, current):
    return current*current * resistance

# %% [markdown]
# Ora chiama la funzione con degli input

# %%
calculate_power(resistance=0.01, current=5)

# %% [markdown]
# ### Classi
#
# Le classi sono una specie di super-funzione, che spesso rendono il codice più pulito e con meno errori.
#
# Di solito **inizializziamo** la classe con alcuni dati o attributi.
#
# Poi possiamo chiamare funzioni specifiche della classe, che chiamiamo **metodi**.

# %%
class Conductor():
    def __init__(self, resistance):
        self.resistance = resistance
    def calc_loss(self,current):
        return current*current * self.resistance

# %% [markdown]
# Prima dobbiamo inizializzare un nuovo oggetto a partire dalla classe. Diciamo che è di tipo `Conductor`.

# %%
line1 = Conductor(resistance=0.01)
type(line1)

# %% [markdown]
# Poi possiamo usare l'oggetto e tutti i suoi metodi `def`.

# %%
line1.calc_loss(current=5)

# %%
line1.calc_loss(current=10)

# %% [markdown]
# ### Documentazione
#
# Una buona documentazione riduce gli errori e il tempo necessario per correggerli, quando capitano.
#
# È *estremamente* utile per il tuo io futuro o per un collega.
#
# Cosa succede se passiamo un input non valido, come una stringa? Un errore inaspettato.

# %%
line1.calc_loss(current='5')

# %% [markdown]
# Quindi documentiamo la classe, con commenti `"""` per più righe.
#
# Definiamo anche i tipi dei dati di input e di output. Anche questo riduce gli errori.

# %%
class Conductor():
    """ Conductor class """
    def __init__(self, resistance:float):
        """ Conductor useful calculations

        Args:
            resistance (float): resistance of the line in ohms
        """
        self.resistance = resistance

    def calc_loss(self,current:float)->float:
        """ Calculate the line loss

        Args:
            current (float): current of the line in ohms

        Returns:
            float: power in watts
        """
        return current**2 * self.resistance

line2 = Conductor(resistance=0.01)

line2.calc_loss(current=5)

# %% [markdown]
# Ora se passo il mouse sopra `calc_loss` vedo che l'input non può essere una stringa.

# %% [markdown]
# ## Interprete
#
# <img src="https://raw.githubusercontent.com/woodjmichael/polimi-a2a-machine-learning-course/main/images/interpreter.png?raw=true" width="600">
#
# _L'interprete (il programma python): traduce il codice in azioni che il computer può compiere_
#
# I notebook usano l'interprete, ma è nascosto. Magia!
#
# Solo una volta dovresti scrivere un file `.py` ed eseguire direttamente l'interprete.

# %% [markdown]
# #### 1. Scrivi un file di codice
#
# 1. Clicca sull'icona della cartella all'estrema sinistra dello schermo. È un rettangolo vuoto.
#
# 2. Nell'area della barra laterale fai clic destro, seleziona `New File`, e chiamalo `hello.py`.
#
# 3. Fai doppio clic su `hello.py` per aprirlo. Scrivi `print('hello!')` e salva (Ctrl+S).

# %% [markdown]
# #### 2. Esegui con l'interprete
#
# Esegui il blocco di codice qui sotto. Il simbolo `!` ci dà accesso diretto al computer cloud di Google.
#
# Il comando `python` esegue l'interprete e `hello.py` è il file che vogliamo eseguire.

# %%
# !python hello.py

# %% [markdown]
# Il risultato è lo stesso di digitare `print('hello!')` in Colab.
#
# La differenza è che abbiamo usato solo due cose: un file di testo e l'interprete python.

# %% [markdown]
# # Ambiente
#
# <img src="https://raw.githubusercontent.com/woodjmichael/polimi-a2a-machine-learning-course/main/images/packages.png?raw=true" width="400">
#
# _L'**ambiente** è l'insieme di "librerie" di codice, programmi e sistema operativo a cui il tuo codice ha accesso._
#
# In python le librerie sono per lo più **pacchetti** che troviamo online. Ogni pacchetto è composto da **moduli.**
#
# > **NB:** La potenza e la popolarità di Python sono dovute soprattutto ai numerosi pacchetti utili (e gratuiti).

# %% [markdown]
# ## Moduli
#
# In `hello.py` abbiamo dovuto scrivere (o copiare e incollare) tutto il codice a mano.
#
# E se un tuo collega ti desse un codice `.py`? O se ne trovassi uno online?
#
# Potresti eseguire il codice direttamente. Più probabilmente, vorrai integrarlo nel tuo codice usando `import`.
#
# Esegui il codice qui sotto per creare un nuovo file chiamato `hello_module.py`.

# %% [markdown]
# #### 1. Scrivi un file modulo
#
# 1. Nell'area della barra laterale fai clic destro, seleziona `New File`, e chiamalo `hello_module.py`.
# 2. Fai doppio clic su `hello_module.py` per aprirlo.
# 3. Scrivi le due righe seguenti e salva (Ctrl+S).
# ```python
# def say_hello():
#     print('hello from a module!')
# ```
#
# Nota che il codice non verrà eseguito: c'è la funzione, ma nessun codice che la chiami.
#
# Questo è ciò che lo rende un **modulo** e non uno script.

# %% [markdown]
# #### 2. Esegui nel notebook

# %% [markdown]
# Di solito importare un modulo non è nulla di spettacolare.

# %%
import hello_module

# %% [markdown]
# Ma ora puoi eseguire la nostra funzione dal modulo.

# %%
hello_module.say_hello()

# %% [markdown]
# ## Pacchetti
#
# <img src="https://raw.githubusercontent.com/woodjmichael/polimi-a2a-machine-learning-course/main/images/package-module.png?raw=true" width="400">
#
# Vogliamo avere accesso a tutte le grandi "librerie" di codice scritte dalla comunità open source.
#
# Per esempio c'è lo strumento di machine learning di Google, `tensorflow`.
#
# Questi gruppi sviluppano **pacchetti**, che sono semplicemente cartelle contenenti da pochi a molti moduli.
#
# Usiamo sempre pacchetti, spesso senza rendercene conto. Altrimenti il python "puro" sarebbe molto noioso.
#
# `pip` ci mostrerà tutti i pacchetti attualmente installati sul computer collegato al notebook.
#
# Vedrai `tensorflow` e alcuni nomi curiosi come `weasel` e `kiwisolver`.

# %%
# !pip list

# %% [markdown]
# Ora troviamo, installiamo e usiamo un nuovo pacchetto.
#
# [meteostat](https://pypi.org/project/meteostat/) sembra interessante!
#
# > NB: I pacchetti hanno quasi sempre del codice di esempio per iniziare

# %%
# !pip install meteostat

# %% [markdown]
# Eseguiamo il codice di esempio, ma cambiamo la posizione con Milano

# %%
# Import Meteostat library and dependencies
import meteostat

# Create Point for Milan, Italy
location = meteostat.Point(45.503, 9.162)

# Get daily data
data = meteostat.Daily(location).fetch()

# Plot line chart including average, minimum and maximum temperature
data['2023':'2024'].plot(y=['tavg', 'tmin', 'tmax']);

# %% [markdown]
# `pip` ora mostrerà il nuovo pacchetto, `meteostat`.

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- ---------------
# altair                    5.5.0
# annotated-types           0.8.0
# anyio                     4.3.0
# archspec                  0.2.3
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 2.4.1
# async-lru                 2.0.4
# attrs                     23.2.0
# Babel                     2.14.0
# backports.zstd            1.7.0
# beautifulsoup4            4.12.3
# bibtexparser              1.4.1
# bleach                    6.1.0
# blinker                   1.9.0
# boltons                   23.1.1
# branca                    0.8.1
# Brotli                    1.1.0
# build                     1.4.2
# cached-property           1.5.2
# cachetools                6.2.0
# certifi                   2026.7.22
# cffi                      1.16.0
# chardet                   3.0.4
# charset-normalizer        3.4.2
# ...

# %% [markdown]
# ## Gestione
#
# <img src="https://raw.githubusercontent.com/woodjmichael/polimi-a2a-machine-learning-course/main/images/conda.png?raw=true" width="600">
#
# Gestire l'ambiente è difficile. Perché?
# - Tendiamo a usare molti pacchetti diversi (e ogni pacchetto usa molti sotto-pacchetti)
# - Inoltre i pacchetti vengono aggiornati costantemente, e non sono sempre compatibili
# - Quindi dobbiamo gestire quale versione di quale pacchetto abbiamo, e "risolvere" i problemi di compatibilità
#
# Ci sono diversi approcci a questo problema.
# - Per esempio con il pacchetto `tensorflow` usiamo spesso due strumenti per l'ambiente:
#   - `conda`
#   -  `pip`
#
# Infine, spesso non abbiamo un unico ambiente fisso su un computer, ma diversi ambienti _virtuali_.
#
# Come esempio, cosa succede se installiamo l'ultima versione del pacchetto `numpy`? Il rosso di solito è una brutta notizia.

# %%
# !pip install --force-reinstall -v "numpy>=2.0.0"

# %% [markdown]
# A quanto pare `meteostat` richiede una versione precedente di `numpy`, quindi `pip` esegue il downgrade di `numpy`.

# %%
# !pip install meteostat

# %% [markdown]
# # Numpy
#
# Numpy è ispirato a matlab ed è particolarmente utile per il calcolo matriciale.
#
# È un pacchetto, quindi dobbiamo importarlo.
#
# > NB: la sintassi `import` .. `as` ci permette semplicemente di definire un soprannome più breve per il pacchetto

# %%
import numpy as np

# %% [markdown]
# Un array numpy è come una lista, e viene costruito a partire da una lista.

# %%
x = np.array([10,20,30])
x

# %% [markdown]
# E si accede ad esso come a una lista. Ricorda che 0 è il primo elemento.

# %%
x[2] # 3rd item

# %% [markdown]
# Ecco un array bidimensionale, o matrice, che di solito rappresentiamo con una lettera maiuscola.

# %%
X = np.array([[10,20,30],
              [40,50,60]])
X

# %% [markdown]
# Le dimensioni sono $2\times3$.

# %%
X.shape

# %% [markdown]
# Per accedere a un valore abbiamo bisogno delle virgole tra le dimensioni.

# %%
X[1,2] # row 1, col 2

# %% [markdown]
# Assegniamo i valori in modo simile.

# %%
X[1,2] = -60
print(X)

# %% [markdown]
# Possiamo facilmente eseguire operazioni algebriche semplici, come la moltiplicazione e l'addizione "scalare".

# %%
x = 2*x + x
x

# %% [markdown]
# E possiamo eseguire operazioni di algebra matriciale, come $X \times x$.

# %%
np.matmul(X,x)

# %% [markdown]
# Ci sono molti metodi utili per un array numpy.

# %%
X.max(), X.min(), X.sum(), X.mean()

# %% [markdown]
# >NB: Queste virgole creano un oggetto tupla (si pronuncia "TOO-pull"), comodo per mantenere le cose compatte

# %% [markdown]
# # Calcolo matriciale e parallelizzazione
#
#
# Il machine learning e l'AI, nel loro nucleo, comportano molta algebra lineare, specialmente moltiplicazioni e addizioni tra matrici.
#
# Per esempio, una rete neurale a singolo strato con 24 unità e 96 valori di input:
# - Ogni passaggio in avanti (forward pass) richiede una moltiplicazione matriciale $24\times96$
# - Una CPU a singolo thread eseguirà ciascuna delle $24\times96=2304$ moltiplicazioni in sequenza
# - Una GPU invece eseguirà molte delle colonne in parallelo, impiegando una frazione del tempo
# - L'addestramento della rete neurale richiede _molti_ passaggi in avanti e il calcolo dei gradienti dell'errore
#
# Il vantaggio della GPU
# - I grandi modelli di machine learning possono avere milioni di parametri e GB di dati di addestramento
# - In molte applicazioni in tempo reale il modello deve calcolare gli output in millisecondi
# - Il tempo di addestramento può essere di giorni o settimane
# - Il vantaggio della parallelizzazione su GPU può essere un addestramento 5-20 volte più veloce
# - Il costo è rappresentato dalla spesa per l'hardware, dalla complessità e dall'energia
#
# Prima e ora
# - Le GPU originali furono sviluppate per l'elaborazione grafica (anch'essa una moltiplicazione matriciale veloce e su larga scala)
# - Nel frattempo i "cluster" di CPU erano comuni nei laboratori e nelle università
# - Ora il principale produttore, NVIDIA, è un elemento critico per lo sviluppo dell'AI
# - Ci sono molti livelli di codice che devono funzionare perfettamente con l'hardware GPU per ottenere buone prestazioni
# - Tuttavia le nuove CPU hanno più core per _alcune_ operazioni parallele
#
#
# <img src="https://raw.githubusercontent.com/woodjmichael/polimi-a2a-machine-learning-course/main/images/gpu.gif?raw=true" width="600">

# %% [markdown]
# # Progetto di codice
#
# Se abbiamo tempo faremo:
# 1. Creare un nuovo notebook
# 2. Creare un nuovo modulo con la classe `Conductor`
# 3. Importarlo in Colab e usare la classe
